# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sqlite3 as sql
import os

sns.set()
con = sql.connect("./data.db")

con.execute(('CREATE TABLE IF NOT EXISTS "clusper" ( "ln" INTEGER,"epoch" INTEGER,"val_loss" REAL,"val_categorical_accuracy" REAL,"loss" REAL,"categorical_accuracy" REAL,"use_batch_norm" TEXT,"optimizer" TEXT,"activation" TEXT,"layers" TEXT,"train_size" INTEGER,"reduction_method" TEXT,"number_of_feature" INTEGER, "clustering_method" TEXT);'))
#con.execute(('CREATE INDEX "cRM" on "clusper" ("reduction_method");')
#con.execute(('CREATE INDEX "cNF" on "clusper" ("number_of_feature");')
#con.execute(('CREATE INDEX "CM" on "clusper" ("clustering_method");')

con.enable_load_extension(True)
con.load_extension("./extension-functions")

if not os.path.exists("graphs"):
    os.makedirs("graphs")

# %%
def generate_sql_z_query(z_name: str, filters: dict):
    where_close = ""
    first_key = True
    for k, lf in filters.items():
        if first_key:
            first_key = False
        else:
            where_close += "AND "
        where_close += "("
        first = True
        for v in lf:
            if not first:
                where_close += " OR "
            else:
                first = False
            where_close += str(k)+"='"+str(v)+"'"
        where_close += ") "
    query = "SELECT DISTINCT "+z_name+" FROM clusper"
    if where_close != "":
        query += " WHERE " + where_close
    return query


def generate_sql_xy_query(x_name: str, y_name: str, z_name: str, z_value, filters: dict, x_limit):
    where_close = z_name+" = '"+str(z_value)+"' "
    for k, lf in filters.items():
        where_close += "AND ("
        first = True
        for v in lf:
            if not first:
                where_close += " OR "
            else:
                first = False
            where_close += str(k)+"='"+str(v)+"'"
        where_close += ") "
    if x_limit > 0:
        where_close += "AND " + x_name + " < " + str(x_limit) + " "
    query = ("SELECT " + x_name + ","
             "min(" + y_name + ") as min,"
             "max(" + y_name + ") as max,"
             "median(" + y_name + ") as median,"
             "avg(" + y_name + ") as mean "
             "FROM clusper ")
    if where_close != "":
        query += "WHERE " + where_close
    query += "GROUP BY " + x_name
    return query


def consolidate_data_from_db(con, x_name: str, y_name: str, z_name: str, filters: dict, x_limit=-1):
    z_value_df = pd.read_sql_query(generate_sql_z_query(z_name, filters), con)
    cd = dict()
    for i in z_value_df.get(z_name):
        query = generate_sql_xy_query(x_name, y_name, z_name, i, filters, x_limit)
        print("Selecting data for", z_name, "=", i)
        # print(query)
        cd[i] = pd.read_sql_query(query, con)
    return cd


def generate_plot(con, x_arg_name, y_arg_name, z_arg_name, filters, save_to_file=True, x_limit=-1, x_name=None, y_name=None,title=''):
    if x_name is None:
        x_name = x_arg_name
    if y_name is None:
        y_name = y_arg_name
        
    cd = consolidate_data_from_db(con, x_arg_name, y_arg_name, z_arg_name, filters, x_limit)

    plt.figure()
    plt.title(title)
    plt.axes()
    for a, d in cd.items():
        plt.plot(d.get(x_arg_name), d.get('median'), 
                 label=z_arg_name.replace('_', ' ') + ' = ' + str(a).replace('_', ' '))
        # plt.fill_between(d.get(x_arg_name), d.get('mean') - d.get('std'), d.get('mean') + d.get('std'), alpha=0.3)
        plt.fill_between(d.get(x_arg_name), d.get('min'), d.get('max'), alpha=0.3)
    if y_arg_name == "val_categorical_accuracy":
        plt.ylabel("Validation accuracy")
    else:
        plt.ylabel(y_name.replace('_',' '))
    plt.xlabel(x_name.replace('_',' '))
    plt.legend()
    # plt.title("Evolution of acuracy acording to the number of training examples")
    if save_to_file:
        algo_name = "all_"
        if "reduction_method" in filters.keys():
            algo_name = '_'.join(map(str, filters["reduction_method"])) + '_'
        layers = ""
        if "layers" in filters.keys():
            layers = '_' + '_'.join(map(lambda x: x.replace('(','').replace(')','').replace(',',''), filters["layers"]))
        plt.savefig("graphs/clusper_"+algo_name+x_name+"_"+y_name+"_"+z_arg_name+layers+".png")
    plt.show()

# %%
generate_plot(con=con,
              x_arg_name='epoch',
              y_arg_name='val_categorical_accuracy',
              z_arg_name='reduction_method',
              filters={},
              x_limit=1500)
# Out:
# Selecting data for reduction_method = reduction_method
# Selecting data for reduction_method = PCA
# Selecting data for reduction_method = ICA
# Selecting data for reduction_method = random
# Selecting data for reduction_method = FA
# /home/qifan/.local/lib/python3.5/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-dc585e6c9307> in <module>
#       4               z_arg_name='reduction_method',
#       5               filters={},
# ----> 6               x_limit=1500)
#
# <ipython-input-3-a382902b397e> in generate_plot(con, x_arg_name, y_arg_name, z_arg_name, filters, save_to_file, x_limit, x_name, y_name, title)
#      74                  label=z_arg_name.replace('_', ' ') + ' = ' + str(a).replace('_', ' '))
#      75         # plt.fill_between(d.get(x_arg_name), d.get('mean') - d.get('std'), d.get('mean') + d.get('std'), alpha=0.3)
# ---> 76         plt.fill_between(d.get(x_arg_name), d.get('min'), d.get('max'), alpha=0.3)
#      77     if y_arg_name == "val_categorical_accuracy":
#      78         plt.ylabel("Validation accuracy")
#
# ~/.local/lib/python3.5/site-packages/matplotlib/pyplot.py in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2571     return gca().fill_between(
#    2572         x=x, y1=y1, y2=y2, where=where, interpolate=interpolate,
# -> 2573         step=step, data=data, **kwargs)
#    2574
#    2575 # Autogenerated by boilerplate.py.  Do not edit as changes will be lost.
#
# ~/.local/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.local/lib/python3.5/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5023
#    5024         # Convert the arrays so we can work with them
# -> 5025         x = ma.masked_invalid(self.convert_xunits(x))
#    5026         y1 = ma.masked_invalid(self.convert_yunits(y1))
#    5027         y2 = ma.masked_invalid(self.convert_yunits(y2))
#
# ~/.local/lib/python3.5/site-packages/numpy/ma/core.py in masked_invalid(a, copy)
#    2361         cls = type(a)
#    2362     else:
# -> 2363         condition = ~(np.isfinite(a))
#    2364         cls = MaskedArray
#    2365     result = a.view(cls)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
generate_plot(con=con,
              x_arg_name='epoch',
              y_arg_name='categorical_accuracy',
              z_arg_name='reduction_method',
              filters={},
              x_limit=1500)
# Out:
# Selecting data for reduction_method = ICA
# Selecting data for reduction_method = LDA
# Selecting data for reduction_method = PCA
# Selecting data for reduction_method = random

# %%
generate_plot(con=con,
              x_arg_name='epoch',
              y_arg_name='val_categorical_accuracy',
              z_arg_name='clustering_method',
              filters={},
              x_limit=1500)
# Out:
# Selecting data for clustering_method = EM
# Selecting data for clustering_method = kmeans

# %%
generate_plot(con=con,
              x_arg_name='epoch',
              y_arg_name='val_categorical_accuracy',
              z_arg_name='layers',
              filters={},
              x_limit=1500)
# Out:
# Selecting data for layers = ()
# Selecting data for layers = (35,)
# Selecting data for layers = (25,)
# Selecting data for layers = (15,)
# Selecting data for layers = (10,)
# Selecting data for layers = (30, 10)
# Selecting data for layers = (20, 10)

# %% [markdown]
# # Specific:

# %%
generate_plot(con=con,
              x_arg_name='epoch',
              y_arg_name='val_categorical_accuracy',
              z_arg_name='clustering_method',
              filters={'reduction_method': ['PCA']},
              x_limit=1500)
# Out:
# Selecting data for clustering_method = EM
# Selecting data for clustering_method = kmeans

# %%
generate_plot(con=con,
              x_arg_name='epoch',
              y_arg_name='val_categorical_accuracy',
              z_arg_name='clustering_method',
              filters={'reduction_method': ['ICA']},
              x_limit=1500)
# Out:
# Selecting data for clustering_method = EM
# Selecting data for clustering_method = kmeans

# %%
generate_plot(con=con,
              x_arg_name='epoch',
              y_arg_name='val_categorical_accuracy',
              z_arg_name='clustering_method',
              filters={'reduction_method': ['random']},
              x_limit=1500)
# Out:
# Selecting data for clustering_method = EM
# Selecting data for clustering_method = kmeans

# %%
generate_plot(con=con,
              x_arg_name='epoch',
              y_arg_name='val_categorical_accuracy',
              z_arg_name='clustering_method',
              filters={'reduction_method': ['FA']},
              x_limit=1500)
# Out:
# Selecting data for clustering_method = EM
# Selecting data for clustering_method = kmeans
